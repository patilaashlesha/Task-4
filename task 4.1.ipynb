# %%
import cv2

# %%
import numpy

# %%
picture=numpy.zeros((300,300,3))

# %%
    picture[0:25,0:25]=[255,255,255]
    picture[0:25,50:75]=[255,255,255]
    picture[0:25,100:125]=[255,255,255]
    picture[0:25,150:175]=[255,255,255]
    picture[0:25,200:225]=[255,255,255]
    picture[0:25,250:275]=[255,255,255]
    
    picture[25:50,25:50]=[255,255,255]
    picture[25:50,75:100]=[255,255,255]
    picture[25:50,125:150]=[255,255,255]
    picture[25:50,175:200]=[255,255,255]
    picture[25:50,225:250]=[255,255,255]
    picture[25:50,275:300]=[255,255,255]
    
    picture[50:75,0:25]=[255,255,255]
    picture[50:75,50:75]=[255,255,255]
    picture[50:75,100:125]=[255,255,255]
    picture[50:75,150:175]=[255,255,255]
    picture[50:75,200:225]=[255,255,255]
    picture[50:75,250:275]=[255,255,255]
    
    picture[75:100,25:50]=[255,255,255]
    picture[75:100,75:100]=[255,255,255]
    picture[75:100,125:150]=[255,255,255]
    picture[75:100,175:200]=[255,255,255]
    picture[75:100,225:250]=[255,255,255]
    picture[75:100,275:300]=[255,255,255]
    
    picture[100:125,0:25]=[255,255,255]
    picture[100:125,50:75]=[255,255,255]
    picture[100:125,100:125]=[255,255,255]
    picture[100:125,150:175]=[255,255,255]
    picture[100:125,200:225]=[255,255,255]
    picture[100:125,250:275]=[255,255,255]
    
    picture[125:150,25:50]=[255,255,255]
    picture[125:150,75:100]=[255,255,255]
    picture[125:150,125:150]=[255,255,255]
    picture[125:150,175:200]=[255,255,255]
    picture[125:150,225:250]=[255,255,255]
    picture[124:150,275:300]=[255,255,255]
    
    picture[150:175,0:25]=[255,255,255]
    picture[150:175,50:75]=[255,255,255]
    picture[150:175,100:125]=[255,255,255]
    picture[150:175,150:175]=[255,255,255]
    picture[150:175,200:225]=[255,255,255]
    picture[150:175,250:275]=[255,255,255]
    
    picture[175:200,25:50]=[255,255,255]
    picture[175:200,75:100]=[255,255,255]
    picture[175:200,125:150]=[255,255,255]
    picture[175:200,175:200]=[255,255,255]
    picture[175:200,225:250]=[255,255,255]
    picture[175:200,275:300]=[255,255,255]
    
    picture[200:225,0:25]=[255,255,255]
    picture[200:225,50:75]=[255,255,255]
    picture[200:225,100:125]=[255,255,255]
    picture[200:225,150:175]=[255,255,255]
    picture[200:225,200:225]=[255,255,255]
    picture[200:225,250:275]=[255,255,255]
    
    picture[225:250,25:50]=[255,255,255]
    picture[225:250,75:100]=[255,255,255]
    picture[225:250,125:150]=[255,255,255]
    picture[225:250,175:200]=[255,255,255]
    picture[225:250,225:250]=[255,255,255]
    picture[225:250,275:300]=[255,255,255]
    
    picture[250:275,0:25]=[255,255,255]
    picture[250:275,50:75]=[255,255,255]
    picture[250:275,100:125]=[255,255,255]
    picture[250:275,150:175]=[255,255,255]
    picture[250:275,200:225]=[255,255,255]
    picture[250:275,250:275]=[255,255,255]
    
    picture[275:300,25:50]=[255,255,255]
    picture[275:300,75:100]=[255,255,255]
    picture[275:300,125:150]=[255,255,255]
    picture[275:300,175:200]=[255,255,255]
    picture[275:300,225:250]=[255,255,255]
    picture[275:300,275:300]=[255,255,255]

# %%
cv2.imshow("hi",picture),
cv2.waitKey()
cv2.destroyAllWindows()
